# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv("DE_electricity_data.csv")


filtered_df = df[(df['datetime'] >= "2024-07-01")]

fig = px.scatter(filtered_df, x="datetime", y="carbon_intensity_avg")

filtered_df.to_csv('DE-hourly-start-july.csv', index=False)

fig.show()
